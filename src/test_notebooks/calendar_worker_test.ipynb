# %% [markdown]
# # Calendar Worker Test

# %%
from dotenv import load_dotenv
import os
from IPython.display import Markdown
from langchain_core.messages import HumanMessage


import sys
from pathlib import Path

project_root = Path(".").resolve().parent.parent
sys.path.append(str(project_root))
os.chdir(project_root)


load_dotenv()

from agents.calendar.worker import google_calendar_worker

test_user_email = "malejandroquesada@gmail.com"
user_id = "manuel-test"
config = {"configurable": {"thread_id": "testing_state_graph01"}}

# %%
response = await google_calendar_worker.ainvoke(
    {"workers_messages": [HumanMessage(content="Hi. how ypu can help me?")], "user_id": user_id,
     "account_name": test_user_email
     }, config)
Markdown(response["workers_messages"][-1].content)
# Out:
# ```json
# {
#   "answer": "I can assist you with managing your calendar, including creating, updating, deleting, and finding events. Additionally, I can help you find free time slots in your schedule. Please let me know what you need assistance with!",
#   "events": []
# }
# ```

# %%
response = await google_calendar_worker.ainvoke(
    {"workers_messages": [HumanMessage(content="create an event to take the car to the mechanic tomorrow in the afternoon, at any time")], "user_id": user_id,
     "account_name": test_user_email
     }, config)
Markdown(response["workers_messages"][-1].content)
# Out:
# ```json
# {
#   "answer": "The event for taking the car to the mechanic has been created successfully based on the account: malejandroquesada@gmail.com.",
#   "events": [
#     {
#       "title": "Car Maintenance Appointment",
#       "start": "2025-07-04T09:00:00-04:00",
#       "end": "2025-07-04T10:30:00-04:00",
#       "event_link": "https://www.google.com/calendar/event?eid=ODFmZnRrODYxNmlydHBhYm45MG8zcW5ncWsgbWFsZWphbmRyb3F1ZXNhZGFAbQ",
#       "attendees": [],
#       "meet_link": "https://meet.google.com/ecf-qymn-zey",
#       "description": null
#     }
#   ]
# }
# ```
