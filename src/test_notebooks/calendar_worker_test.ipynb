# %% [markdown]
# # Calendar Worker Test

# %%
from dotenv import load_dotenv
import os
from IPython.display import Markdown
from langchain_core.messages import HumanMessage


import sys
from pathlib import Path

project_root = Path(".").resolve().parent.parent
src_path = project_root /"src"
sys.path.append(str(src_path))
os.chdir(project_root)


load_dotenv()
os.environ["TESTING"] = "true"

from agents.calendar.worker import google_calendar_worker

test_user_email = "manuel.quesada@student.uhasselt.be"
user_id = "manuel-test"
config = {"configurable": {"thread_id": "testing_state_graph01"}}

# %%
response = await google_calendar_worker.ainvoke(
    {"workers_messages": [HumanMessage(content="Hi. how you can help me?")], "user_id": user_id,
     "account_name": test_user_email
     }, config)
Markdown(response["workers_messages"][-1].content)
# Out:
# I can assist you with managing your calendar, including creating, updating, finding, and deleting events. I can also help you find free time slots in your schedule. If you have any specific requests or questions about your calendar, feel free to let me know!

# %%
response = await google_calendar_worker.ainvoke(
    {"workers_messages": [HumanMessage(content="create an event to take the car to the mechanic today in the afternoon, at any time")], "user_id": user_id,
     "account_name": test_user_email
     }, config)
Markdown(response["workers_messages"][-1].content)
# Out:
# ```json
# {
#   "answer": "The event to take the car to the mechanic has been successfully created for today in the afternoon. This answer is based on the account: manuel.quesada@student.uhasselt.be.",
#   "events": [
#     {
#       "title": "Take the car to the mechanic",
#       "start": "2025-08-23T15:00:00+02:00",
#       "end": "2025-08-23T16:30:00+02:00",
#       "event_link": "https://www.google.com/calendar/event?eid=ajRtZWJkOWs5NzVndWRiaDgybHRicmF1bTQgbWFudWVsLnF1ZXNhZGFAc3R1ZGVudC51aGFzc2VsdC5iZQ",
#       "attendees": [],
#       "meet_link": "https://meet.google.com/uye-fxen-hex",
#       "description": "Scheduled maintenance or repair at the mechanic."
#     }
#   ]
# }
# ```
