# %%
from dotenv import load_dotenv
import os
from IPython.display import Markdown
from langchain_core.messages import HumanMessage


import sys
from pathlib import Path

project_root = Path(".").resolve().parent.parent
sys.path.append(str(project_root))
os.chdir(project_root)


load_dotenv()
from agents.search.worker import google_search_worker

# %%
response = await google_search_worker.ainvoke(
    {"workers_messages": [HumanMessage(content="Hi. how you can help me?")],
     })
Markdown(response["workers_messages"][-1].content)
# Out:
# I can help you find information by searching the web for answers to your questions. Just let me know what you're curious about or need assistance with, and I'll provide you with the top results from a Google search.

# %%
response = await google_search_worker.ainvoke(
    {"workers_messages": [HumanMessage(content="Tell me the difference between agents and workflows")],
     })
Markdown(response["workers_messages"][-1].content)
# Out:
# ```json
# {
#   "answer": "The main difference between agents and workflows is that workflows are systems where tasks are executed through predefined code paths, making them suitable for static, repetitive processes. Agents, however, are systems where tasks are dynamically directed by the system itself, allowing for adaptability and control over task execution, making them ideal for dynamic, multi-step reasoning tasks.",
#   "results": [
#     {
#       "url": "https://langchain-ai.github.io/langgraph/tutorials/workflows/",
#       "content": "Workflows are systems where LLMs and tools are orchestrated through predefined code paths. Agents, on the other hand, are systems where LLMs dynamically direct ..."
#     },
#     {
#       "url": "https://medium.com/@vipra_singh/ai-agent-workflow-vs-agent-part-5-2026a890a33d",
#       "content": "Workflows work best for static, repetitive processes, while Agents are ideal for dynamic, multi-step reasoning tasks where adaptability is key."
#     },
#     {
#       "url": "https://www.louisbouchard.ai/agents-vs-workflows/",
#       "content": "Agents “are systems where LLMs dynamically direct their own processes and tools usage, maintaining control over how they accomplish tasks” ..."
#     }
#   ]
# }
# ```

# %%
response
# Out:
# {'workers_messages': [SystemMessage(content='## ROLE:\nYou are a Google Search agent that uses the google_search_tool (via SerpAPI) to answer user questions.\n\n## Your goal is to achieve the following outcome:\nGiven a user query, answer the question using the Google Search tool and return the top 3 clean, relevant, and trustworthy results.\n\n\n## Your task is as follows:\nUse the tool **once** to search Google for the user\'s query.\nDo not call any tools after that.\nYour response **must** be in the following JSON format:\n```json\n{{\n  "answer": "string - the answer to the user\'s query",\n  "results": [\n    {{\n      "url": "string - the result\'s URL",\n      "content": "string - a clean paragraph summary of the result"\n    }},\n    ...\n  ]\n}}\n\nGuidelines:\n- Strip any HTML, formatting tags, or noise from snippets.\n- Summarize only useful, trustworthy content.\n- Avoid ads, broken links, or vague/duplicate responses.\n- Return exactly 3 results (if available).\n- Keep summaries concise and in plain English.\n- URLs must be exact and clickable.\n- After gathering the 3 results, do NOT call any tools again.\n- Respond directly using the format below and finish.\n\n\n## Structure your response as follows:\n```json\n{{\n  "answer": "string - the answer to the user\'s query",\n  "results": [\n    {{\n      "url": "<url1>",\n      "content": "<clean summary1>"\n    }},\n    {{\n      "url": "<url2>",\n      "content": "<clean summary2>"\n    }},\n    {{\n      "url": "<url3>",\n      "content": "<clean summary3>"\n    }}\n  ]\n}}\n\n\nNow perform the task as instructed above.', additional_kwargs={}, response_metadata={}, id='d5a80329-5a27-4aa7-8fe8-09d0402b54c1'),
#   HumanMessage(content='Tell me the difference between agents and workflows', additional_kwargs={}, response_metadata={}, id='4db472a0-a1f5-4c3d-a233-6a45ceb9d026'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_CAjKA10iHxTGGN6iU6v549Uy', 'function': {'arguments': '{"query":"difference between agents and workflows"}', 'name': 'google_search_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 433, 'total_tokens': 452, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_df0f7b956c', 'id': 'chatcmpl-C6sLhOHLJFRtQVcchaTDzVEL14Mka', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--c5bb8ed4-c9fe-4f0a-99f0-76f9da10e558-0', tool_calls=[{'name': 'google_search_tool', 'args': {'query': 'difference between agents and workflows'}, 'id': 'call_CAjKA10iHxTGGN6iU6v549Uy', 'type': 'tool_call'}], usage_metadata={'input_tokens': 433, 'output_tokens': 19, 'total_tokens': 452, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="{'answer': 'Top 3 search results for: difference between agents and workflows', 'results': [{'url': 'https://langchain-ai.github.io/langgraph/tutorials/workflows/', 'content': 'Workflows are systems where LLMs and tools are orchestrated through predefined code paths. Agents, on the other hand, are systems where LLMs dynamically direct ...'}, {'url': 'https://medium.com/@vipra_singh/ai-agent-workflow-vs-agent-part-5-2026a890a33d', 'content': 'Workflows work best for static, repetitive processes, while Agents are ideal for dynamic, multi-step reasoning tasks where adaptability is key.'}, {'url': 'https://www.louisbouchard.ai/agents-vs-workflows/', 'content': 'Agents “are systems where LLMs dynamically direct their own processes and tools usage, maintaining control over how they accomplish tasks” ...'}]}", name='google_search_tool', id='1f02ced7-85e5-4af4-839d-84a19e26d595', tool_call_id='call_CAjKA10iHxTGGN6iU6v549Uy'),
#   AIMessage(content='```json\n{\n  "answer": "The main difference between agents and workflows is that workflows are systems where tasks are executed through predefined code paths, making them suitable for static, repetitive processes. Agents, however, are systems where tasks are dynamically directed by the system itself, allowing for adaptability and control over task execution, making them ideal for dynamic, multi-step reasoning tasks.",\n  "results": [\n    {\n      "url": "https://langchain-ai.github.io/langgraph/tutorials/workflows/",\n      "content": "Workflows are systems where LLMs and tools are orchestrated through predefined code paths. Agents, on the other hand, are systems where LLMs dynamically direct ..."\n    },\n    {\n      "url": "https://medium.com/@vipra_singh/ai-agent-workflow-vs-agent-part-5-2026a890a33d",\n      "content": "Workflows work best for static, repetitive processes, while Agents are ideal for dynamic, multi-step reasoning tasks where adaptability is key."\n    },\n    {\n      "url": "https://www.louisbouchard.ai/agents-vs-workflows/",\n      "content": "Agents “are systems where LLMs dynamically direct their own processes and tools usage, maintaining control over how they accomplish tasks” ..."\n    }\n  ]\n}\n```', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 273, 'prompt_tokens': 655, 'total_tokens': 928, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_df0f7b956c', 'id': 'chatcmpl-C6sLjyMyuFqYI3JLiodLzAMMxNeGp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--0d2addc2-1f23-422e-ac46-a0fc49dac742-0', usage_metadata={'input_tokens': 655, 'output_tokens': 273, 'total_tokens': 928, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  'num_calls': ['perform_google_search']}
