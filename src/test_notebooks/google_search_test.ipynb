# %%
from dotenv import load_dotenv
import os
from IPython.display import Markdown
from langchain_core.messages import HumanMessage

import sys
from pathlib import Path

project_root = Path(".").resolve().parent.parent
src_path = project_root /"src"
sys.path.append(str(src_path))
os.chdir(project_root)


load_dotenv()
# Out:
# True

# %%
from agents.search.worker import google_search_worker

# %%
response = await google_search_worker.ainvoke(
    {"workers_messages": [HumanMessage(content="Hi. how you can help me?")],
     })
Markdown(response["workers_messages"][-1].content)
# Out:
# 🔁 LLM RESPONSE:
# content='```json\n{\n  "answer": "I can assist you by providing information and answering questions using Google search results.",\n  "results": []\n}\n```' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 434, 'total_tokens': 466, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_34a54ae93c', 'id': 'chatcmpl-C1sPojIa3pJ096aOdBLM4OE89fP69', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--cd141ecd-a41f-4ec3-8413-b552f7461e14-0' usage_metadata={'input_tokens': 434, 'output_tokens': 32, 'total_tokens': 466, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ✅ LLM is done, no tool call.
# ```json
# {
#   "answer": "I can assist you by providing information and answering questions using Google search results.",
#   "results": []
# }
# ```

# %%
response = await google_search_worker.ainvoke(
    {"workers_messages": [HumanMessage(content="Tell me the difference between agents and workflows")],
     })
Markdown(response["workers_messages"][-1].content)
# Out:
# 🔁 LLM RESPONSE:
# content='' additional_kwargs={'tool_calls': [{'id': 'call_yMWi7IcVsjbuJKMDwGVHayPQ', 'function': {'arguments': '{"query":"difference between agents and workflows"}', 'name': 'google_search_tool'}, 'type': 'function'}], 'refusal': None} response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 434, 'total_tokens': 453, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_62a23a81ef', 'id': 'chatcmpl-C1sRFVG0sdAF0gtTr4OOXLpVH0McV', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='run--5066ff59-6c9d-47ca-814a-214dbe833540-0' tool_calls=[{'name': 'google_search_tool', 'args': {'query': 'difference between agents and workflows'}, 'id': 'call_yMWi7IcVsjbuJKMDwGVHayPQ', 'type': 'tool_call'}] usage_metadata={'input_tokens': 434, 'output_tokens': 19, 'total_tokens': 453, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 🔧 LLM is calling a tool.
# 🔁 LLM RESPONSE:
# content='' additional_kwargs={'tool_calls': [{'id': 'call_ysJpio15oa6jztEEKITpNli4', 'function': {'arguments': '{"query":"difference between agents and workflows"}', 'name': 'google_search_tool'}, 'type': 'function'}], 'refusal': None} response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 492, 'total_tokens': 511, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_34a54ae93c', 'id': 'chatcmpl-C1sRGsFHjmC1bXjH3WiLH1smrhdcU', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='run--4942cc57-a458-4ef1-9111-809b36b7cb78-0' tool_calls=[{'name': 'google_search_tool', 'args': {'query': 'difference between agents and workflows'}, 'id': 'call_ysJpio15oa6jztEEKITpNli4', 'type': 'tool_call'}] usage_metadata={'input_tokens': 492, 'output_tokens': 19, 'total_tokens': 511, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 🔧 LLM is calling a tool.
# 🔁 LLM RESPONSE:
# content='' additional_kwargs={'tool_calls': [{'id': 'call_1rGQkDDbuVrvsesoudZYwELn', 'function': {'arguments': '{"query":"difference between agents and workflows"}', 'name': 'google_search_tool'}, 'type': 'function'}], 'refusal': None} response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 550, 'total_tokens': 569, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_62a23a81ef', 'id': 'chatcmpl-C1sRI7QEcU84ByXfih24nwEJoLpt8', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='run--1a74887d-513f-4e9f-b0f8-cc1f097a7f5c-0' tool_calls=[{'name': 'google_search_tool', 'args': {'query': 'difference between agents and workflows'}, 'id': 'call_1rGQkDDbuVrvsesoudZYwELn', 'type': 'tool_call'}] usage_metadata={'input_tokens': 550, 'output_tokens': 19, 'total_tokens': 569, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 🔧 LLM is calling a tool.
# 🔁 LLM RESPONSE:
# content='' additional_kwargs={'tool_calls': [{'id': 'call_lYCcXoICfCjquk9YGuhGqGDh', 'function': {'arguments': '{"query":"difference between agents and workflows"}', 'name': 'google_search_tool'}, 'type': 'function'}], 'refusal': None} response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 608, 'total_tokens': 627, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_62a23a81ef', 'id': 'chatcmpl-C1sRJt0iSPcDkmiVjjKNnY3YIapdG', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='run--92757b31-1a64-44f1-9a64-61844eb6160d-0' tool_calls=[{'name': 'google_search_tool', 'args': {'query': 'difference between agents and workflows'}, 'id': 'call_lYCcXoICfCjquk9YGuhGqGDh', 'type': 'tool_call'}] usage_metadata={'input_tokens': 608, 'output_tokens': 19, 'total_tokens': 627, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 🔧 LLM is calling a tool.
# 🔁 LLM RESPONSE:
# content='' additional_kwargs={'tool_calls': [{'id': 'call_qa8nWPUS1FV6bpGG1pXotFBl', 'function': {'arguments': '{"query":"difference between agents and workflows"}', 'name': 'google_search_tool'}, 'type': 'function'}], 'refusal': None} response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 666, 'total_tokens': 685, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_34a54ae93c', 'id': 'chatcmpl-C1sRMWUuj4gG0Pc6p7rKg0LdRk9Xl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='run
 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 🔧 LLM is calling a tool.
# 🔁 LLM RESPONSE:
# content='' additional_kwargs={'tool_calls': [{'id': 'call_XveDzOIvasmLiOyuFqREdP8A', 'function': {'arguments': '{"query":"difference between agents and workflows"}', 'name': 'google_search_tool'}, 'type': 'function'}], 'refusal': None} response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 1130, 'total_tokens': 1149, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_34a54ae93c', 'id': 'chatcmpl-C1sRZuZ7hdTyo7EOBHTdpfFTuEswS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='run--4e149824-f96f-4901-b3e1-3e695f72a01f-0' tool_calls=[{'name': 'google_search_tool', 'args': {'query': 'difference between agents and workflows'}, 'id': 'call_XveDzOIvasmLiOyuFqREdP8A', 'type': 'tool_call'}] usage_metadata={'input_tokens': 1130, 'output_tokens': 19, 'total_tokens': 1149, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 🔧 LLM is calling a tool.
# ---------------------------------------------------------------------------
# GraphRecursionError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 response = await google_search_worker.ainvoke(
#       2     {"workers_messages": [HumanMessage(content="Tell me the difference between agents and workflows")],
#       3      })
#       4 Markdown(response["workers_messages"][-1].content)
#
# File d:\Utkarsh\UTKARSH\GenAI\Ready_Tensor\multi_agent\Google-Workspace-Agent\search-agent\Lib\site-packages\langgraph\pregel\main.py:3101, in Pregel.ainvoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3098 chunks: list[dict[str, Any] | Any] = []
#    3099 interrupts: list[Interrupt] = []
# -> 3101 async for chunk in self.astream(
#    3102     input,
#    3103     config,
#    3104     context=context,
#    3105     stream_mode=["updates", "values"]
#    3106     if stream_mode == "values"
#    3107     else stream_mode,
#    3108     print_mode=print_mode,
#    3109     output_keys=output_keys,
#    3110     interrupt_before=interrupt_before,
#    3111     interrupt_after=interrupt_after,
#    3112     durability=durability,
#    3113     **kwargs,
#    3114 ):
#    3115     if stream_mode == "values":
#    3116         if len(chunk) == 2:
#
# File d:\Utkarsh\UTKARSH\GenAI\Ready_Tensor\multi_agent\Google-Workspace-Agent\search-agent\Lib\site-packages\langgraph\pregel\main.py:2966, in Pregel.astream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2957 if loop.status == "out_of_steps":
#    2958     msg = create_error_message(
#    2959         message=(
#    2960             f"Recursion limit of {config['recursion_limit']} reached "
#    (...)   2964         error_code=ErrorCode.GRAPH_RECURSION_LIMIT,
#    2965     )
# -> 2966     raise GraphRecursionError(msg)
#    2967 # set final channel values as run output
#    2968 await run_manager.on_chain_end(loop.output)
#
# GraphRecursionError: Recursion limit of 25 reached without hitting a stop condition. You can increase the limit by setting the `recursion_limit` config key.
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/GRAPH_RECURSION_LIMIT
