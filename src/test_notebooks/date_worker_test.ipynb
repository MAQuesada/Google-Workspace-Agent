# %%
from dotenv import load_dotenv
import os
from IPython.display import Markdown
from langchain_core.messages import HumanMessage


import sys
from pathlib import Path

project_root = Path(".").resolve().parent.parent
sys.path.append(str(project_root))
os.chdir(project_root)


load_dotenv()

from agents.dates.worker import calculate_date

# %%
print(calculate_date("Tommorrow in the afternoon after 2 PM"))
# Out:
# The requested date range is from 2025-07-11T14:00:00+02:00 to 2025-07-11T15:00:00+02:00 ('Europe/Paris' time zone).

# %%
print(calculate_date("thursday of next week from 5 to 9 PM"))
# Out:
# The requested date range is from 2025-07-17T17:00:00+02:00 to 2025-07-17T21:00:00+02:00 ('Europe/Paris' time zone).
